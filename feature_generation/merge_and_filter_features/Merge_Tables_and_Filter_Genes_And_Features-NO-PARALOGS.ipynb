# %% [markdown]
# **update 14.08:**
# 1. New features were added: Hic, disorder, CUB (updated), TF (transcription factors), target features (in the past they were part of the CUB table).
# 2. In previous version, we removed from 'full_table' the genes with more than **10%** missing values. Now I changed the threshold such that genes with more than **5%** missing values are filtered.

# %% [markdown]
# **update 22.09:**
#
# 1. New Target Gene Features (Bar) - longest common string, and profile features (GC content, mRNA folding, Codon and AA usage).
# 2. New conservation features (H) - conservation and entropy.
# 3. Because the new entropy features include many missing values (only 4700 genes are in the table) , and because they are still significant for the learning, we decided to increase the threshold and remove genes with more than 10% missing values.
# 4. After the above filtering, the remaining tables is filtered again and features are removed if they have more than 600 missing values (used to be 1000).

# %% [markdown]
# **update 26.10:**
# * filter paralogs genes - we don't want our software to suggest them.

# %%
import pandas as pd
import numpy as np
from os import chdir
import matplotlib.pyplot as plt

# %%
directory = r'/home/karinsio/my_project_dir/iGEM/Merge_Features'
chdir(directory)

# %%
## load all feature tables and set their index to 'ORF' (change the name of column if needed)
old_features_df = pd.read_csv(r'Not_normalized_table.csv', index_col='ORF') #updated features from 10-genes project. 
bar_df = pd.read_csv(r'final table with nan1.csv', index_col='ORF') #SGD, LFE, co-expression, ATG-context, shifted-ORF.
bar_df_HiC = pd.read_csv(r'HiC.csv', index_col='ORF').rename(columns={'Rank':'Rank_HiC'}) #HiC data - NEW July
noa_df_biogrid = pd.read_excel(r'biogrid final.xlsx').rename(columns={'Systematic name ':'ORF'}).set_index('ORF')
noa_df_yeastmine = pd.read_excel(r'yeastmine.xlsx').rename(columns={'BioEntity.secondaryIdentifier':'ORF'}).set_index('ORF')
noa_df_disorder = pd.read_excel(r'disorder_output.xlsx').rename(columns={'gene name':'ORF'}).set_index('ORF') #new August
karin_df = pd.read_excel(r'CUB_results_final.xlsx', index_col='ORF') #codon usage bias
h_df = pd.read_csv(r'not_normalized_smf_dmf_ranks_feature.csv').rename(columns={'genes':'ORF'}).set_index('ORF') #cellmap
h_df_tfs = pd.read_csv(r'number_of_TF.csv',index_col='ORF') #transcription factors (TFs) - NEW July
h_df_conservation = pd.read_csv(r'conservation features gene names converted.csv',index_col='ORF') #conservation - NEW SEPTEMBER
h_df_entropy = pd.read_csv(r'entropy features gene names converted.csv',index_col='ORF') # entropy (part of conservation) - NEW SEPTEMBER

# %%
## load the target gene features of GFP. Attention: for a NEW target gene, these columns will be replaced in order to
# implement the GFP-trained model on the new target gene. 
target_gene_GFP_df = pd.read_excel(r'Target_gene_df_GFP_updated.xlsx', index_col='ORF') #GFP (22.09: now include CAI, RCA, longest common string, and profile features.). 
#in the future, it will include ChimeraARS score (bar is working on it). 
target_gene_GFP_df = target_gene_GFP_df.drop(['Unnamed: 0'],axis=1)

# %%
## drop dulpications and unnamed columns
karin_df = karin_df.drop(['ORF.1','Unnamed: 0','mRNA_RPKM'],axis=1) #mRNA_RPKM is a duplication of 'mRNA' from old_features
h_df = h_df.drop(['Unnamed: 0'],axis=1)
noa_df_disorder = noa_df_disorder.drop(['disorder_percentage1','disorder_percentage2'],axis=1) #duplications of 'disorder_percentage_both_algorithms' column

# %%
# Rename repeating features names
old_features_df.rename(columns={'ranks': 'rank_STRING', 'weighted_rank': 'weighted_rank_STRING'}, inplace=True)
h_df.rename(columns={'rank': 'rank_TheCellMap','positive_rank': 'positive_rank_TheCellMap',
                        'negative_rank': 'negative_rank_TheCellMap',
                         'positive_weighted_rank': 'positive_weighted_rank_TheCellMap',
                        'negative_weighted_rank': 'negative_weighted_rank_TheCellMap',
                        'absolute_weighted_rank': 'absolute_weighted_rank_TheCellMap'}, inplace=True)

# %%
# Deleting 'gene_sequence' and 'BioEntity.name' because it is not numeric
karin_df = karin_df.drop(['gene_sequence'],axis=1);
noa_df_yeastmine = noa_df_yeastmine.drop(['BioEntity.name'],axis=1)

# %%
# Joining tables
full_table = old_features_df.join([bar_df, bar_df_HiC, noa_df_biogrid, noa_df_yeastmine, noa_df_disorder, karin_df, h_df, h_df_tfs,h_df_conservation,h_df_entropy, target_gene_GFP_df], how = 'left')
# full_table = old_features_df.join([bar_df, bar_df_HiC, noa_df_biogrid, noa_df_yeastmine, noa_df_disorder, karin_df, h_df, h_df_tfs, target_gene_GFP_df], how = 'left')
full_table.rename_axis('ORF',  inplace = True)
full_table
# Out:
#            gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0010             23.772610     22.480620     20.930233     27.906977
# Q0017             29.012346     35.185185     24.074074     27.777778
# Q0032             11.340206      9.278351     14.432990     10.309278
# Q0045             29.906542     38.130841     37.196262     14.392523
# Q0050             24.950100     30.898204     32.934132     11.017964
# ...                     ...           ...           ...           ...
# YPR201W           37.777778     38.518519     36.296296     38.518519
# YPR202W           37.796374     42.259414     28.870293     42.259414
# YPR203W           42.071197     45.631068     36.893204     43.689320
# YPR204C-A         45.341615     52.173913     34.161491     49.689441
# YPR204W           46.402065     45.498548     44.046467     49.661181
#
#            molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0010           118925.1220        68.756624     0.271318           4.684387
# Q0017            49700.8551        68.736876     0.129630           9.895935
# Q0032            89586.7189        61.968730     0.247423           9.469543
# Q0045           495095.9411        73.508043     0.127103           6.583801
# Q0050           776944.8206        71.145017     0.082635           9.887512
# ...                     ...              ...          ...                ...
# YPR201W         375605.9314        77.146690     0.120988           8.867004
# YPR202W         221684.9174        77.112802     0.125523           6.603333
# YPR203W          95653.1186        77.976827     0.087379           9.158752
# YPR204C-A       147818.2145        79.785522     0.142857           9.587830
# YPR204W         961086.6613        81.277966     0.079380           6.327332
#
#            helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                               ...
# Q0010        0.689922   0.224806  ...                                0.285714
# Q0017        0.518519   0.240741  ...                                0.285714
# Q0032        0.649485   0.164948  ...                                0.285714
# Q0045        0.431776   0.257944  ...                                0.142857
# Q0050        0.361677   0.233533  ...                                0.190476
# ...               ...        ...  ...                                     ...
# YPR201W      0.434568   0.217284  ...                                0.190476
# YPR202W      0.338912   0.205021  ...                                0.142857
# YPR203W      0.310680   0.203883  ...                                0.142857
# YPR204C-A    0.422360   0.204969  ...                                0.142857
# YPR204W      0.273959   0.226525  ...                                0.190476
#
#            FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0010                                   0.500000
# Q0017                                   0.500000
# Q0032                                   0.500000
# Q0045                                   0.416667
# Q0050                                   0.500000
# ...                                          ...
# YPR201W                                 0.500000
# YPR202W                                 0.500000
# YPR203W                                 0.500000
# YPR204C-A                               0.500000
# YPR204W                                 0.500000
#
#            GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  1.099215
# Q0017                                  0.983570
# Q0032                                  1.146844
# Q0045                                  1.075778
# Q0050                                  1.047111
# ...                                         ...
# YPR201W                                1.604667
# YPR202W                                1.773556
# YPR203W                                1.696000
# YPR204C-A                              1.631944
# YPR204W                                1.675481
#
#            CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  6.882708
# Q0017                                  6.422266
# Q0032                                  6.787585
# Q0045                                  9.387726
# Q0050                                  9.461169
# ...                                         ...
# YPR201W                                9.363919
# YPR202W                                8.145436
# YPR203W                                8.236142
# YPR204C-A                              8.372434
# YPR204W                                8.111308
#
#            AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                   0.054669
# Q0017                                   0.053498
# Q0032                                   0.054986
# Q0045                                   0.056127
# Q0050                                   0.055935
# ...                                          ...
# YPR201W                                 0.057632
# YPR202W                                 0.056591
# YPR203W                                 0.057069
# YPR204C-A                               0.057723
# YPR204W                                 0.054769
#
#            FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0010                                282.647998                   1.437037
# Q0017                                215.253997                   1.557037
# Q0032                                286.917998                   1.320000
# Q0045                                143.539998                   1.400000
# Q0050                                159.681998                   1.473333
# ...                                         ...                        ...
# YPR201W                              173.243999                   0.720000
# YPR202W                              185.225999                   0.680000
# YPR203W                              175.941999                   0.633333
# YPR204C-A                            193.362499                   0.608333
# YPR204W                              119.487999                   0.622222
#
#            CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0010                      11.773242                    0.716532
# Q0017                      12.747872                    0.735342
# Q0032                      12.610575                    0.704781
# Q0045                      12.401977                    0.441886
# Q0050                      13.785043                    0.461040
# ...                              ...                         ...
# YPR201W                     4.706676                    0.258301
# YPR202W                     7.794569                    0.309640
# YPR203W                     7.274332                    0.274786
# YPR204C-A                   6.399492                    0.228112
# YPR204W                     7.031987                    0.387169
#
#            FE_neighbors_dist_L1_dist
# ORF
# Q0010                      39.940000
# Q0017                      34.320000
# Q0032                      43.420000
# Q0045                      21.960000
# Q0050                      23.080000
# ...                              ...
# YPR201W                    31.739999
# YPR202W                    44.120001
# YPR203W                    44.960000
# YPR204C-A                  27.950000
# YPR204W                    42.760000
#
# [6720 rows x 1970 columns]

# %%
# Geting rid of Unnamed columns
full_table.drop(full_table.columns[full_table.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
full_table.shape
# Out:
# (6720, 1970)

# %%
# Deleting 'gene_length' beacuse it is less informative than 'length' column
"""first_length = full_table['gene_length']-----> has 887 NaNs
second_length = full_table['length']-----> has 37 NaNs
"""
del full_table['gene_length']

# %%
# Geting rid of features with a lot of missing numbers
full_table.drop(['CAI','dS', 'dN', 'dN/dS', 'dS adjusted', 'dN/dS adjusted', 'Starvation STD'], axis = 1, inplace = True)

# %%
full_table.shape
# Out:
# (6720, 1962)

# %%
full_table.index.drop_duplicates(keep='first') #print the size of full_table without duplications in rows.
# Out:
# Index(['Q0010', 'Q0017', 'Q0032', 'Q0045', 'Q0050', 'Q0055', 'Q0060', 'Q0065',
#        'Q0070', 'Q0075',
#        ...
#        'YPR196W', 'YPR197C', 'YPR198W', 'YPR199C', 'YPR200C', 'YPR201W',
#        'YPR202W', 'YPR203W', 'YPR204C-A', 'YPR204W'],
#       dtype='object', name='ORF', length=6713)

# %%
## drop duplications according to 'ORF' column because we used the 'join' metric to combine the tables.
full_table = full_table.reset_index().drop_duplicates(subset='ORF',keep='first').set_index('ORF')

# %%
full_table
# Out:
#            gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0010             23.772610     22.480620     20.930233     27.906977
# Q0017             29.012346     35.185185     24.074074     27.777778
# Q0032             11.340206      9.278351     14.432990     10.309278
# Q0045             29.906542     38.130841     37.196262     14.392523
# Q0050             24.950100     30.898204     32.934132     11.017964
# ...                     ...           ...           ...           ...
# YPR201W           37.777778     38.518519     36.296296     38.518519
# YPR202W           37.796374     42.259414     28.870293     42.259414
# YPR203W           42.071197     45.631068     36.893204     43.689320
# YPR204C-A         45.341615     52.173913     34.161491     49.689441
# YPR204W           46.402065     45.498548     44.046467     49.661181
#
#            molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0010           118925.1220        68.756624     0.271318           4.684387
# Q0017            49700.8551        68.736876     0.129630           9.895935
# Q0032            89586.7189        61.968730     0.247423           9.469543
# Q0045           495095.9411        73.508043     0.127103           6.583801
# Q0050           776944.8206        71.145017     0.082635           9.887512
# ...                     ...              ...          ...                ...
# YPR201W         375605.9314        77.146690     0.120988           8.867004
# YPR202W         221684.9174        77.112802     0.125523           6.603333
# YPR203W          95653.1186        77.976827     0.087379           9.158752
# YPR204C-A       147818.2145        79.785522     0.142857           9.587830
# YPR204W         961086.6613        81.277966     0.079380           6.327332
#
#            helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                               ...
# Q0010        0.689922   0.224806  ...                                0.285714
# Q0017        0.518519   0.240741  ...                                0.285714
# Q0032        0.649485   0.164948  ...                                0.285714
# Q0045        0.431776   0.257944  ...                                0.142857
# Q0050        0.361677   0.233533  ...                                0.190476
# ...               ...        ...  ...                                     ...
# YPR201W      0.434568   0.217284  ...                                0.190476
# YPR202W      0.338912   0.205021  ...                                0.142857
# YPR203W      0.310680   0.203883  ...                                0.142857
# YPR204C-A    0.422360   0.204969  ...                                0.142857
# YPR204W      0.273959   0.226525  ...                                0.190476
#
#            FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0010                                   0.500000
# Q0017                                   0.500000
# Q0032                                   0.500000
# Q0045                                   0.416667
# Q0050                                   0.500000
# ...                                          ...
# YPR201W                                 0.500000
# YPR202W                                 0.500000
# YPR203W                                 0.500000
# YPR204C-A                               0.500000
# YPR204W                                 0.500000
#
#            GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  1.099215
# Q0017                                  0.983570
# Q0032                                  1.146844
# Q0045                                  1.075778
# Q0050                                  1.047111
# ...                                         ...
# YPR201W                                1.604667
# YPR202W                                1.773556
# YPR203W                                1.696000
# YPR204C-A                              1.631944
# YPR204W                                1.675481
#
#            CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  6.882708
# Q0017                                  6.422266
# Q0032                                  6.787585
# Q0045                                  9.387726
# Q0050                                  9.461169
# ...                                         ...
# YPR201W                                9.363919
# YPR202W                                8.145436
# YPR203W                                8.236142
# YPR204C-A                              8.372434
# YPR204W                                8.111308
#
#            AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                   0.054669
# Q0017                                   0.053498
# Q0032                                   0.054986
# Q0045                                   0.056127
# Q0050                                   0.055935
# ...                                          ...
# YPR201W                                 0.057632
# YPR202W                                 0.056591
# YPR203W                                 0.057069
# YPR204C-A                               0.057723
# YPR204W                                 0.054769
#
#            FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0010                                282.647998                   1.437037
# Q0017                                215.253997                   1.557037
# Q0032                                286.917998                   1.320000
# Q0045                                143.539998                   1.400000
# Q0050                                159.681998                   1.473333
# ...                                         ...                        ...
# YPR201W                              173.243999                   0.720000
# YPR202W                              185.225999                   0.680000
# YPR203W                              175.941999                   0.633333
# YPR204C-A                            193.362499                   0.608333
# YPR204W                              119.487999                   0.622222
#
#            CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0010                      11.773242                    0.716532
# Q0017                      12.747872                    0.735342
# Q0032                      12.610575                    0.704781
# Q0045                      12.401977                    0.441886
# Q0050                      13.785043                    0.461040
# ...                              ...                         ...
# YPR201W                     4.706676                    0.258301
# YPR202W                     7.794569                    0.309640
# YPR203W                     7.274332                    0.274786
# YPR204C-A                   6.399492                    0.228112
# YPR204W                     7.031987                    0.387169
#
#            FE_neighbors_dist_L1_dist
# ORF
# Q0010                      39.940000
# Q0017                      34.320000
# Q0032                      43.420000
# Q0045                      21.960000
# Q0050                      23.080000
# ...                              ...
# YPR201W                    31.739999
# YPR202W                    44.120001
# YPR203W                    44.960000
# YPR204C-A                  27.950000
# YPR204W                    42.760000
#
# [6713 rows x 1962 columns]

# %%
full_table.shape ##print the shape
# Out:
# (6713, 1962)

# %% [markdown]
# ## Filter paralogs:

# %%
paralogs_names = pd.read_csv(r'‏‏Gene_YeastParalogs_only_ORF.csv')

# %%
full_table = full_table.drop(paralogs_names['ORF'])

# %%
full_table.shape ##print the shape
# Out:
# (5563, 1962)

# %% [markdown]
# ## Missing values:

# %% [markdown]
# ### Filter genes with too many NaNs:

# %% [markdown]
# Look for 'query_k_plus_sums' function. use: https://stackoverflow.com/questions/14247586/how-to-select-rows-with-one-or-more-nulls-from-a-pandas-dataframe-without-listin

# %%
# Helper : for each row in 'df' specify the number of NaNs.
def row_nan_sums(df):
    sums = []
    for row in df.values:
        sum = 0
        for el in row:
            if el != el: # np.nan is never equal to itself. This is "hacky", but complete.
                sum+=1
        sums.append(sum)
    return sums

# %%
# Returns a list of indices for rows with k+ NaNs
def query_k_plus_sums(df, k):
    sums = row_nan_sums(df)
    indices = []
    i = 0
    for sum in sums:
        if (sum >= k):
            indices.append(i)
        i += 1
    return indices

# %%
## plot the missing values per gene before filtering:
plt.scatter(range(full_table.shape[0]), row_nan_sums(full_table))
plt.xlabel('Gene index')
plt.ylabel('Missing values')
# plt.show()
# Out:
# Text(0, 0.5, 'Missing values')

# %%
## Define the threshold for genes removed from 'full_table':
k=round(0.1*full_table.shape[1]) #threshold
len(query_k_plus_sums(full_table,k)) #number of removed genes
# Out:
# 1528

# %%
k #the threshold. genes that have more than k missing values will be removed.
# Out:
# 196

# %%
full_table.iloc[query_k_plus_sums(full_table,k)] ##removed genes
# Out:
#            gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0010             23.772610     22.480620     20.930233     27.906977
# Q0017             29.012346     35.185185     24.074074     27.777778
# Q0032             11.340206      9.278351     14.432990     10.309278
# Q0050             24.950100     30.898204     32.934132     11.017964
# Q0055             26.510721     31.111111     32.865497     15.555556
# ...                     ...           ...           ...           ...
# YPR197C           37.234043     40.425532     39.893617     31.382979
# YPR202W           37.796374     42.259414     28.870293     42.259414
# YPR203W           42.071197     45.631068     36.893204     43.689320
# YPR204C-A         45.341615     52.173913     34.161491     49.689441
# YPR204W           46.402065     45.498548     44.046467     49.661181
#
#            molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0010           118925.1220        68.756624     0.271318           4.684387
# Q0017            49700.8551        68.736876     0.129630           9.895935
# Q0032            89586.7189        61.968730     0.247423           9.469543
# Q0050           776944.8206        71.145017     0.082635           9.887512
# Q0055           795237.7014        72.022549     0.092398           9.672668
# ...                     ...              ...          ...                ...
# YPR197C         173791.4201        76.358936     0.095745          10.075134
# YPR202W         221684.9174        77.112802     0.125523           6.603333
# YPR203W          95653.1186        77.976827     0.087379           9.158752
# YPR204C-A       147818.2145        79.785522     0.142857           9.587830
# YPR204W         961086.6613        81.277966     0.079380           6.327332
#
#            helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                               ...
# Q0010        0.689922   0.224806  ...                                0.285714
# Q0017        0.518519   0.240741  ...                                0.285714
# Q0032        0.649485   0.164948  ...                                0.285714
# Q0050        0.361677   0.233533  ...                                0.190476
# Q0055        0.347368   0.250292  ...                                0.190476
# ...               ...        ...  ...                                     ...
# YPR197C      0.345745   0.207447  ...                                0.190476
# YPR202W      0.338912   0.205021  ...                                0.142857
# YPR203W      0.310680   0.203883  ...                                0.142857
# YPR204C-A    0.422360   0.204969  ...                                0.142857
# YPR204W      0.273959   0.226525  ...                                0.190476
#
#            FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0010                                   0.500000
# Q0017                                   0.500000
# Q0032                                   0.500000
# Q0050                                   0.500000
# Q0055                                   0.416667
# ...                                          ...
# YPR197C                                 0.500000
# YPR202W                                 0.500000
# YPR203W                                 0.500000
# YPR204C-A                               0.500000
# YPR204W                                 0.500000
#
#            GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  1.099215
# Q0017                                  0.983570
# Q0032                                  1.146844
# Q0050                                  1.047111
# Q0055                                  1.079111
# ...                                         ...
# YPR197C                                1.602444
# YPR202W                                1.773556
# YPR203W                                1.696000
# YPR204C-A                              1.631944
# YPR204W                                1.675481
#
#            CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                  6.882708
# Q0017                                  6.422266
# Q0032                                  6.787585
# Q0050                                  9.461169
# Q0055                                  9.935381
# ...                                         ...
# YPR197C                                8.392262
# YPR202W                                8.145436
# YPR203W                                8.236142
# YPR204C-A                              8.372434
# YPR204W                                8.111308
#
#            AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0010                                   0.054669
# Q0017                                   0.053498
# Q0032                                   0.054986
# Q0050                                   0.055935
# Q0055                                   0.056954
# ...                                          ...
# YPR197C                                 0.056647
# YPR202W                                 0.056591
# YPR203W                                 0.057069
# YPR204C-A                               0.057723
# YPR204W                                 0.054769
#
#            FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0010                                282.647998                   1.437037
# Q0017                                215.253997                   1.557037
# Q0032                                286.917998                   1.320000
# Q0050                                159.681998                   1.473333
# Q0055                                171.391998                   1.366667
# ...                                         ...                        ...
# YPR197C                              174.737999                   0.733333
# YPR202W                              185.225999                   0.680000
# YPR203W                              175.941999                   0.633333
# YPR204C-A                            193.362499                   0.608333
# YPR204W                              119.487999                   0.622222
#
#            CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0010                      11.773242                    0.716532
# Q0017                      12.747872                    0.735342
# Q0032                      12.610575                    0.704781
# Q0050                      13.785043                    0.461040
# Q0055                      11.687849                    0.470365
# ...                              ...                         ...
# YPR197C                     7.367588                    0.427218
# YPR202W                     7.794569                    0.309640
# YPR203W                     7.274332                    0.274786
# YPR204C-A                   6.399492                    0.228112
# YPR204W                     7.031987                    0.387169
#
#            FE_neighbors_dist_L1_dist
# ORF
# Q0010                      39.940000
# Q0017                      34.320000
# Q0032                      43.420000
# Q0050                      23.080000
# Q0055                      21.699999
# ...                              ...
# YPR197C                    35.000000
# YPR202W                    44.120001
# YPR203W                    44.960000
# YPR204C-A                  27.950000
# YPR204W                    42.760000
#
# [1528 rows x 1962 columns]

# %%
## Remove from 'full_table' the genes with more than 25% missing values.
full_table.drop(full_table.iloc[query_k_plus_sums(full_table,k)].index,axis=0,inplace=True)

# %%
full_table
# Out:
#          gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0045           29.906542     38.130841     37.196262     14.392523
# Q0085           23.717949     28.461538     31.538462     11.153846
# Q0105           27.720207     36.010363     33.160622     13.989637
# Q0140           10.359231     13.283208     13.283208      4.511278
# Q0250           26.719577     40.873016     32.936508      6.349206
# ...                   ...           ...           ...           ...
# YPR194C         37.319666     39.977221     35.763098     36.218679
# YPR198W         37.622549     40.441176     39.338235     33.088235
# YPR199C         38.983051     43.389831     37.627119     35.932203
# YPR200C         37.659033     45.801527     36.641221     30.534351
# YPR201W         37.777778     38.518519     36.296296     38.518519
#
#          molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0045         495095.9411        73.508043     0.127103           6.583801
# Q0085         240575.1586        70.002141     0.130769           7.850525
# Q0105         357332.7138        72.151406     0.147668           8.927429
# Q0140         370392.4967        63.815998     0.082707           9.896179
# Q0250         233883.9746        71.684708     0.103175           4.447083
# ...                   ...              ...          ...                ...
# YPR194C       813698.0620        77.370216     0.181093           7.212219
# YPR198W       504033.0093        77.479446     0.134191           8.370667
# YPR199C       274219.4629        77.704317     0.088136           8.343079
# YPR200C       121949.0440        75.968670     0.099237           8.478088
# YPR201W       375605.9314        77.146690     0.120988           8.867004
#
#          helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                             ...
# Q0045      0.431776   0.257944  ...                                0.142857
# Q0085      0.507692   0.219231  ...                                0.142857
# Q0105      0.471503   0.238342  ...                                0.190476
# Q0140      0.393484   0.401003  ...                                0.142857
# Q0250      0.408730   0.182540  ...                                0.142857
# ...             ...        ...  ...                                     ...
# YPR194C    0.412301   0.230068  ...                                0.095238
# YPR198W    0.413603   0.253676  ...                                0.095238
# YPR199C    0.288136   0.250847  ...                                0.190476
# YPR200C    0.320611   0.190840  ...                                0.142857
# YPR201W    0.434568   0.217284  ...                                0.190476
#
#          FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0045                                 0.416667
# Q0085                                 0.500000
# Q0105                                 0.500000
# Q0140                                 0.500000
# Q0250                                 0.416667
# ...                                        ...
# YPR194C                               0.583333
# YPR198W                               0.500000
# YPR199C                               0.500000
# YPR200C                               0.333333
# YPR201W                               0.500000
#
#          GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                1.075778
# Q0085                                1.526593
# Q0105                                1.443852
# Q0140                                1.738889
# Q0250                                1.286111
# ...                                       ...
# YPR194C                              1.711111
# YPR198W                              1.591778
# YPR199C                              1.639111
# YPR200C                              1.566889
# YPR201W                              1.604667
#
#          CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                9.387726
# Q0085                                9.005698
# Q0105                                9.027811
# Q0140                                8.852762
# Q0250                                9.215504
# ...                                       ...
# YPR194C                              9.339576
# YPR198W                              9.212723
# YPR199C                              9.271538
# YPR200C                              9.065875
# YPR201W                              9.363919
#
#          AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                 0.056127
# Q0085                                 0.056295
# Q0105                                 0.056597
# Q0140                                 0.056664
# Q0250                                 0.055073
# ...                                        ...
# YPR194C                               0.056656
# YPR198W                               0.055084
# YPR199C                               0.056694
# YPR200C                               0.056460
# YPR201W                               0.057632
#
#          FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0045                              143.539998                   1.400000
# Q0085                              165.461997                   0.808889
# Q0105                              186.751998                   0.827407
# Q0140                              162.735999                   0.693333
# Q0250                              177.809997                   0.945000
# ...                                       ...                        ...
# YPR194C                            220.981998                   0.573333
# YPR198W                            158.523999                   0.560000
# YPR199C                            204.329999                   0.746667
# YPR200C                            127.613998                   0.700000
# YPR201W                            173.243999                   0.720000
#
#          CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0045                    12.401977                    0.441886
# Q0085                     6.654022                    0.398243
# Q0105                     7.811413                    0.320506
# Q0140                     4.937459                    0.364409
# Q0250                    10.372980                    0.368158
# ...                            ...                         ...
# YPR194C                   3.220144                    0.352380
# YPR198W                   4.596451                    0.380668
# YPR199C                   4.042837                    0.341796
# YPR200C                   4.546339                    0.363847
# YPR201W                   4.706676                    0.258301
#
#          FE_neighbors_dist_L1_dist
# ORF
# Q0045                    21.960000
# Q0085                    31.120000
# Q0105                    33.240000
# Q0140                    39.720000
# Q0250                    19.780000
# ...                            ...
# YPR194C                  35.440001
# YPR198W                  32.100000
# YPR199C                  37.980000
# YPR200C                  38.460000
# YPR201W                  31.739999
#
# [4035 rows x 1962 columns]

# %%
## plot the missing values per gene AFTER filtering:
plt.scatter(range(full_table.shape[0]), row_nan_sums(full_table))
plt.xlabel('Gene index')
plt.ylabel('Missing values')
plt.title('missing values per gene, after filtering the genes with more than 10% missing values')
# plt.show()
# Out:
# Text(0.5, 1.0, 'missing values per gene, after filtering the genes with more than 10% missing values')

# %% [markdown]
# ### Filter features with too many NaNs:

# %%
## create a list that specifices for each column in 'full_table' the number of NaNs:
nan_values = full_table.isnull().sum()
nan_values = nan_values.sort_values()
## create a list of features with the highest number of missing values:
highest_nan = nan_values[998:]
highest_nan.to_csv('highest_nans.csv')
# Out:
# /home/karinsio/my_project_dir/my_project_env/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
## plot the missing values per feature (before filtering the highest NaNs):
plt.scatter(range(len(nan_values.values)), nan_values.values)
plt.xlabel('Feature index')
plt.ylabel('Missing values')
plt.title('missing values per feature')
# plt.show()
# Out:
# Text(0.5, 1.0, 'missing values per feature')

# %%
## According to the plot above, The threshold is set to 600. 
# All features that have more than 600 missing values are to be removed from further analysis. 
filtered_features=highest_nan>600 #bool

# %%
indices = [i for i, x in enumerate(filtered_features) if x] ## get the indices of true values in 'filtered_features'
len(filtered_features[indices]) #number of filtered features
# Out:
# 13

# %%
full_table.drop(list(filtered_features[indices].keys()),axis=1,inplace=True) ##drop those features

# %%
full_table
# Out:
#          gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0045           29.906542     38.130841     37.196262     14.392523
# Q0085           23.717949     28.461538     31.538462     11.153846
# Q0105           27.720207     36.010363     33.160622     13.989637
# Q0140           10.359231     13.283208     13.283208      4.511278
# Q0250           26.719577     40.873016     32.936508      6.349206
# ...                   ...           ...           ...           ...
# YPR194C         37.319666     39.977221     35.763098     36.218679
# YPR198W         37.622549     40.441176     39.338235     33.088235
# YPR199C         38.983051     43.389831     37.627119     35.932203
# YPR200C         37.659033     45.801527     36.641221     30.534351
# YPR201W         37.777778     38.518519     36.296296     38.518519
#
#          molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0045         495095.9411        73.508043     0.127103           6.583801
# Q0085         240575.1586        70.002141     0.130769           7.850525
# Q0105         357332.7138        72.151406     0.147668           8.927429
# Q0140         370392.4967        63.815998     0.082707           9.896179
# Q0250         233883.9746        71.684708     0.103175           4.447083
# ...                   ...              ...          ...                ...
# YPR194C       813698.0620        77.370216     0.181093           7.212219
# YPR198W       504033.0093        77.479446     0.134191           8.370667
# YPR199C       274219.4629        77.704317     0.088136           8.343079
# YPR200C       121949.0440        75.968670     0.099237           8.478088
# YPR201W       375605.9314        77.146690     0.120988           8.867004
#
#          helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                             ...
# Q0045      0.431776   0.257944  ...                                0.142857
# Q0085      0.507692   0.219231  ...                                0.142857
# Q0105      0.471503   0.238342  ...                                0.190476
# Q0140      0.393484   0.401003  ...                                0.142857
# Q0250      0.408730   0.182540  ...                                0.142857
# ...             ...        ...  ...                                     ...
# YPR194C    0.412301   0.230068  ...                                0.095238
# YPR198W    0.413603   0.253676  ...                                0.095238
# YPR199C    0.288136   0.250847  ...                                0.190476
# YPR200C    0.320611   0.190840  ...                                0.142857
# YPR201W    0.434568   0.217284  ...                                0.190476
#
#          FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0045                                 0.416667
# Q0085                                 0.500000
# Q0105                                 0.500000
# Q0140                                 0.500000
# Q0250                                 0.416667
# ...                                        ...
# YPR194C                               0.583333
# YPR198W                               0.500000
# YPR199C                               0.500000
# YPR200C                               0.333333
# YPR201W                               0.500000
#
#          GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                1.075778
# Q0085                                1.526593
# Q0105                                1.443852
# Q0140                                1.738889
# Q0250                                1.286111
# ...                                       ...
# YPR194C                              1.711111
# YPR198W                              1.591778
# YPR199C                              1.639111
# YPR200C                              1.566889
# YPR201W                              1.604667
#
#          CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                9.387726
# Q0085                                9.005698
# Q0105                                9.027811
# Q0140                                8.852762
# Q0250                                9.215504
# ...                                       ...
# YPR194C                              9.339576
# YPR198W                              9.212723
# YPR199C                              9.271538
# YPR200C                              9.065875
# YPR201W                              9.363919
#
#          AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                 0.056127
# Q0085                                 0.056295
# Q0105                                 0.056597
# Q0140                                 0.056664
# Q0250                                 0.055073
# ...                                        ...
# YPR194C                               0.056656
# YPR198W                               0.055084
# YPR199C                               0.056694
# YPR200C                               0.056460
# YPR201W                               0.057632
#
#          FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0045                              143.539998                   1.400000
# Q0085                              165.461997                   0.808889
# Q0105                              186.751998                   0.827407
# Q0140                              162.735999                   0.693333
# Q0250                              177.809997                   0.945000
# ...                                       ...                        ...
# YPR194C                            220.981998                   0.573333
# YPR198W                            158.523999                   0.560000
# YPR199C                            204.329999                   0.746667
# YPR200C                            127.613998                   0.700000
# YPR201W                            173.243999                   0.720000
#
#          CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0045                    12.401977                    0.441886
# Q0085                     6.654022                    0.398243
# Q0105                     7.811413                    0.320506
# Q0140                     4.937459                    0.364409
# Q0250                    10.372980                    0.368158
# ...                            ...                         ...
# YPR194C                   3.220144                    0.352380
# YPR198W                   4.596451                    0.380668
# YPR199C                   4.042837                    0.341796
# YPR200C                   4.546339                    0.363847
# YPR201W                   4.706676                    0.258301
#
#          FE_neighbors_dist_L1_dist
# ORF
# Q0045                    21.960000
# Q0085                    31.120000
# Q0105                    33.240000
# Q0140                    39.720000
# Q0250                    19.780000
# ...                            ...
# YPR194C                  35.440001
# YPR198W                  32.100000
# YPR199C                  37.980000
# YPR200C                  38.460000
# YPR201W                  31.739999
#
# [4035 rows x 1949 columns]

# %%
## plot the missing values per feature AFTER filtering the highest NaNs:
nan_values = full_table.isnull().sum()
nan_values = nan_values.sort_values()
plt.scatter(range(len(nan_values.values)), nan_values.values)
plt.xlabel('Feature index')
plt.ylabel('Missing values')
plt.title('missing values per feature, after filtering the features with the highest number of missing values')
# plt.show()
# Out:
# Text(0.5, 1.0, 'missing values per feature, after filtering the features with the highest number of missing values')

# %% [markdown]
# ## Normalize the table:

# %%
normalized_table = full_table.copy()

# %%
# Creating not normalized table with the median value in NaN's places
full_table_not_normalized = full_table.fillna(full_table.median())

# %%
# Checking if there is object type columns
filter_str_columns = normalized_table.dtypes[normalized_table.dtypes == np.object]
listOfColumnNames = list(filter_str_columns.index)
 
print(listOfColumnNames)
# Out:
# []

# %%
# creating numerical table
numerical_cols = [col for col in normalized_table.columns if (col is not 'ORF')]
numerical_table = normalized_table[numerical_cols]

# %%
numerical_normalize_table = (numerical_table-numerical_table.mean())/numerical_table.std() 
        
### fill column with mean values
numerical_normalize_table = numerical_normalize_table.fillna(numerical_normalize_table.mean())

# %%
numerical_normalize_table
# Out:
#          gc_content_total  gc_content_1  gc_content_2  gc_content_3  \
# ORF
# Q0045           -2.827306     -1.456628      0.272788     -3.803033
# Q0085           -4.568122     -3.496139     -0.846180     -4.303174
# Q0105           -3.442310     -1.903893     -0.525358     -3.865249
# Q0140           -8.325854     -6.697648     -4.456601     -5.328971
# Q0250           -3.723781     -0.878231     -0.569682     -5.045144
# ...                   ...           ...           ...           ...
# YPR194C         -0.742036     -1.067178     -0.010655     -0.432468
# YPR198W         -0.656837     -0.969317      0.696416     -0.915895
# YPR199C         -0.274136     -0.347369      0.358001     -0.476708
# YPR200C         -0.646574      0.161322      0.163016     -1.310286
# YPR201W         -0.613172     -1.374857      0.094798     -0.077309
#
#          molecular_weight  MeltingPoint_NN  aromaticity  isoelectric_point  \
# ORF
# Q0045            0.091008        -2.860651     1.399007          -0.237455
# Q0085           -0.658992        -5.056654     1.529023           0.455935
# Q0105           -0.314941        -3.710413     2.128289           1.045420
# Q0140           -0.276458        -8.931487    -0.175333           1.575703
# Q0250           -0.678709        -4.002739     0.550483          -1.407070
# ...                   ...              ...          ...                ...
# YPR194C          1.029838        -0.441490     3.313582           0.106534
# YPR198W          0.117343        -0.373072     1.650370           0.740655
# YPR199C         -0.559852        -0.232219     0.017180           0.725554
# YPR200C         -1.008550        -1.319381     0.410838           0.799456
# YPR201W         -0.261095        -0.581501     1.182156           1.012345
#
#          helix_perc  turn_perc  ...  AAU_neighbors_dist_target_gene_ks_dist  \
# ORF                             ...
# Q0045      2.364957   0.519496  ...                               -0.515728
# Q0085      3.785383  -0.392223  ...                               -0.515728
# Q0105      3.108261   0.057858  ...                                0.768024
# Q0140      1.648501   3.888616  ...                               -0.515728
# Q0250      1.933767  -1.256321  ...                               -0.515728
# ...             ...        ...  ...                                     ...
# YPR194C    2.000573  -0.136991  ...                               -1.799480
# YPR198W    2.024939   0.418995  ...                               -1.799480
# YPR199C   -0.322598   0.352370  ...                                0.768024
# YPR200C    0.285022  -1.060851  ...                               -0.515728
# YPR201W    2.417200  -0.438072  ...                                0.768024
#
#          FE_neighbors_dist_target_gene_ks_dist  \
# ORF
# Q0045                                -2.725173
# Q0085                                -0.125014
# Q0105                                -0.125014
# Q0140                                -0.125014
# Q0250                                -2.725173
# ...                                        ...
# YPR194C                               2.475145
# YPR198W                              -0.125014
# YPR199C                              -0.125014
# YPR200C                              -5.325332
# YPR201W                              -0.125014
#
#          GC_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                               -6.597535
# Q0085                               -1.468947
# Q0105                               -2.410228
# Q0140                                0.946192
# Q0250                               -4.204728
# ...                                       ...
# YPR194C                              0.630184
# YPR198W                             -0.727383
# YPR199C                             -0.188907
# YPR200C                             -1.010526
# YPR201W                             -0.580756
#
#          CU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                1.018863
# Q0085                               -0.349389
# Q0105                               -0.270190
# Q0140                               -0.897139
# Q0250                                0.402043
# ...                                       ...
# YPR194C                              0.846413
# YPR198W                              0.392081
# YPR199C                              0.602731
# YPR200C                             -0.133865
# YPR201W                              0.933596
#
#          AAU_neighbors_dist_target_gene_cart_d  \
# ORF
# Q0045                                -1.563998
# Q0085                                -1.412631
# Q0105                                -1.141168
# Q0140                                -1.080234
# Q0250                                -2.512359
# ...                                        ...
# YPR194C                              -1.087628
# YPR198W                              -2.502084
# YPR199C                              -1.053305
# YPR200C                              -1.264353
# YPR201W                              -0.208855
#
#          FE_neighbors_dist_target_gene_cart_d  GC_neighbors_dist_L1_dist  \
# ORF
# Q0045                               -0.899945                   6.858797
# Q0085                               -0.211932                   1.285628
# Q0105                                0.456246                   1.460226
# Q0140                               -0.297486                   0.196137
# Q0250                                0.175605                   2.568924
# ...                                       ...                        ...
# YPR194C                              1.530541                  -0.935259
# YPR198W                             -0.429678                  -1.060969
# YPR199C                              1.007925                   0.698979
# YPR200C                             -1.399777                   0.258992
# YPR201W                              0.032303                   0.447558
#
#          CU_neighbors_dist_L1_dist  AAU_neighbors_dist_L1_dist  \
# ORF
# Q0045                     4.489407                    2.620161
# Q0085                     1.041616                    1.766704
# Q0105                     1.735853                    0.246486
# Q0140                     0.011972                    1.105057
# Q0250                     3.272355                    1.178371
# ...                            ...                         ...
# YPR194C                  -1.018124                    0.869822
# YPR198W                  -0.192575                    1.423012
# YPR199C                  -0.524649                    0.662841
# YPR200C                  -0.222634                    1.094063
# YPR201W                  -0.126459                   -0.969979
#
#          FE_neighbors_dist_L1_dist
# ORF
# Q0045                    -2.187961
# Q0085                    -0.335603
# Q0105                     0.093109
# Q0140                     1.403510
# Q0250                    -2.628806
# ...                            ...
# YPR194C                   0.537998
# YPR198W                  -0.137425
# YPR199C                   1.051643
# YPR200C                   1.148710
# YPR201W                  -0.210225
#
# [4035 rows x 1949 columns]

# %%
full_table_not_normalized.to_csv('updated_new_features_table.csv')
numerical_normalize_table.to_csv('normalized_updated_new_features_table.csv')
